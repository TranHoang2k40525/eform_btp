# %% [markdown]
# # 02 — Tiền xử lý và chia tập (Tuần 2)
# Tách theo `group_id` để alias của cùng một field không rơi vào cả train và test.

# %%
# %pip install -q -r requirements-training.txt

# %%
# !python prepare_dataset.py --input '../Data/train/mapping_seed.jsonl' --output '../Data/processed' --seed 42

# %%
import json
json.load(open('../Data/processed/manifest.json', encoding='utf-8'))
