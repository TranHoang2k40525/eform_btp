# %% [markdown]
# # 03 — Baseline lexical (Tuần 3)
# Đo exact/alias/fuzzy trước khi dùng embedding. Baseline là mốc bắt buộc để phát hiện regression.

# %%
import sys
sys.path.insert(0, '../Main')
from ai_import.config import Settings
from ai_import.mapping import HybridFieldMapper
from ai_import.models import MapRequest, TargetFieldDto
fields = [TargetFieldDto(field_id='total', label='Tổng số', aliases=['Số lượng', 'Cộng'])]
HybridFieldMapper(Settings(embedding_enabled=False)).map(MapRequest(headers=['Tổng cộng'], target_fields=fields)).model_dump()

# %% [markdown]
# Ghi metric baseline vào `Models/baseline-evaluation.json`; tuyệt đối không chọn model chỉ dựa trên vài ví dụ đẹp.
