# %% [markdown]
# # 07 — Huấn luyện tăng dần (Tuần 6)
# Chỉ nhận feedback đã được người có quyền xác nhận; giữ tập test cố định và không tự động đưa model lên production.

# %%
# !python incremental_training.py --approved-feedback ../Data/processed/approved-feedback.jsonl --existing ../Data/processed/train.jsonl --merged ../Data/processed/incremental-train.jsonl --minimum-new 100

# %% [markdown]
# Sau đó chạy lại notebook 02, 05, 06 với version mới. Chỉ promote nếu qua release gate, security/integration test và phê duyệt; rollback bằng cách đổi lại model version trước.
