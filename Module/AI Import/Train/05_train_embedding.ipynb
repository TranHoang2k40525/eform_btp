# %% [markdown]
# # 05 — Fine-tune multilingual E5 (Tuần 4–5)
# Không train LLM từ đầu. Chỉ chạy khi có tối thiểu 20 mẫu kỹ thuật; để dùng thật nên có từ 500 feedback đã xác nhận và đủ loại biểu mẫu.

# %%
# !nvidia-smi || true

# %%
# %pip install -q -r requirements-training.txt

# %%
# !python train_embedding.py --config config/training.yaml --train ../Data/processed/train.jsonl --validation ../Data/processed/validation.jsonl --output ../Models/mapping-e5-v1

# %% [markdown]
# Nếu GPU hết bộ nhớ: giảm `batch_size` 16 → 8 → 4. Giữ seed và lưu metadata để tái lập.
