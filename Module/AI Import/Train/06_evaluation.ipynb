# %% [markdown]
# # 06 — Đánh giá và chặn release (Tuần 5–6)
# Đánh giá trên tập test thật, chưa từng dùng để train; theo dõi top‑1, top‑3 và MRR.

# %%
# !python evaluate_model.py --model ../Models/mapping-e5-v1 --test ../Data/processed/test.jsonl --output ../Models/mapping-e5-v1/evaluation.json

# %%
# !python compare_release.py --baseline ../Models/baseline-evaluation.json --candidate ../Models/mapping-e5-v1/evaluation.json --min-top1 0.85 --min-top3 0.95

# %% [markdown]
# Ngoài metric tổng, lập confusion table theo loại form và kiểm tra thủ công các mapping confidence cao nhưng sai.
